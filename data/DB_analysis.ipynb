# %%
import pandas as pd
df = pd.read_csv('FINAL.csv')
# Out:
# /var/folders/06/jyj0qcdd21x4khc3d50khblm0000gn/T/ipykernel_2853/3485714662.py:2: DtypeWarning: Columns (14,15,16,19,20,21,26,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('FINAL.csv')

# %%
ThreeD = pd.read_csv('CHECK/3D.csv')
BA = pd.read_csv('CHECK/BA.csv')
Cytokine = pd.read_csv('CHECK/Cytokine.csv')
#Binding
KD = pd.read_csv('CHECK/KD.csv')
ON = pd.read_csv('CHECK/ON.csv')
OFF = pd.read_csv('CHECK/OFF.csv')
Qual = pd.read_csv('CHECK/Qualitative-binding.csv')

# %%
ThreeD_Method = list(set(ThreeD['Method'].values))
BA_Method = list(set(BA['Method'].values))
Cytokine_Method = list(set(Cytokine['Method'].values))

Binding_Method = list(set(KD['Method'].values))+list(set(ON['Method'].values))\
                 +list(set(OFF['Method'].values))+list(set(Qual['Method'].values))

# %%
BA_Method += [
 'antigen-loaded-target, CTL culture',
 'multimer-sort',
 'cultured-T-cells,beads,tetramer-sort',
 'Tetramer-sort',
 'dextramer-sort,cultured-T-cells',
 'tetramer-sort,beads',
 'beads,tetramer-sort',
 'dextramer-sort,beads',
 'cultured-T-cells,tetramer-sort',
 'cultured-T-cells',
 'cd8null-tetramer-sort',
 'tetramer sort',
 'tetramer-sort,cultured-T-cells',
 'CTL clone',
 'pentamer-sort',
 'dextramer-sort',
 'peptide-restimulation,tetramer-sort',
 'cla',
 'MHC-peptide-beads,cultivated-t-cells',
 'streptamer-sort',
 'tetramer-sort'
]
Binding_Method += [
    'limited-dilution-cloning,antigen-expressing-targets',
    'antigen-loaded-targets',
    'antigen-expressing-targets'
    'antigen-loaded-target,limiting-dilution-cloning',
    'antigen-loaded-targets, limiting-dilution-cloning',
     'tetramer-sort,limiting-dilution-cloning',
     'antigen-loaded-targets,antigen-expressing-targets',
     'cultured-T-cells,antigen-expressing-targets',
     'antigen-loaded-targets,cloning-by-limiting-dilution',
      'antigen-loaded-targets, pentamer-sort',
     'antigen-loaded-targets,cultured-T-cells',
      'limiting-dilution-cloning,tetramer-sort',
      'limiting-diffusion-cloning,antigen-expressing-targets',
      'tetramer-sort,antigen-loaded-targed',
      'antigen-loaded-targets,pentamer-sort',
      'antigen-loaded-targets,dextramer-sort',
      'tetramer-sort,antigen-expressing cells,cultured-T-cells',
      'antigen-loaded-targets, tetramer-sort',
       'limiting-dilution-cloning',
       'antigen-loaded-targets,limiting-dilution-cloning',


]
Cytokine_Method += [
 'antigen-loaded-targets, IFNg capture assay',
  'antigen loaded targets, IFNg capture assay',

]

# %%
BA_Method = list(set(BA_Method))
Binding_Method = list(set(Binding_Method))
Cytokine_Method = list(set(Cytokine_Method))
ThreeD_Method = list(set(ThreeD_Method))

# %%
ThreeD_Method

# %%
df = df[df['Database source'] == 'VDJ']
VDJ_Method = list(set(df['Method'].values))
VDJ_Method
# Out:
# [nan,
#  'antigen-loaded-target, CTL culture',
#  'multimer-sort',
#  'cultured-T-cells,beads,tetramer-sort',
#  'Tetramer-sort',
#  'limited-dilution-cloning,antigen-expressing-targets',
#  'antigen-loaded-targets',
#  'antigen-expressing-targets',
#  'antigen-loaded-target,limiting-dilution-cloning',
#  'dextramer-sort,cultured-T-cells',
#  'tetramer-sort,beads',
#  'beads,tetramer-sort',
#  'antigen-loaded-targets, limiting-dilution-cloning',
#  'dextramer-sort,beads',
#  'cultured-T-cells,tetramer-sort',
#  'cultured-T-cells',
#  'cd8null-tetramer-sort',
#  'tetramer sort',
#  'tetramer-sort,cultured-T-cells',
#  'CTL clone',
#  'pentamer-sort',
#  'tetramer-sort,limiting-dilution-cloning',
#  'dextramer-sort',
#  'antigen-loaded-targets,antigen-expressing-targets',
#  'cultured-T-cells,antigen-expressing-targets',
#  'peptide-restimulation,tetramer-sort',
#  'antigen-loaded-targets,cloning-by-limiting-dilution',
#  'antigen-loaded-targets, pentamer-sort',
# ...

# %%
methods = df[['Method','Response measured']].values
methods = [f'{method}_{response}' for method,response in methods]
methods = list(set(methods))

# %%
len(methods)
# Out:
# 155

# %%
methods
# Out:
# ['cytometric bead array_granzyme A release',
#  'ELISPOT_granzyme B release',
#  'multimer-sort_nan',
#  'bioassay_IFNg release',
#  'cultured-T-cells,tetramer-sort_nan',
#  'cultured-T-cells_nan',
#  'in vitro assay_proliferation',
#  'reporter gene assay_IL-2 release',
#  'cd8null-tetramer-sort_nan',
#  'in vitro assay_cytotoxicity',
#  'ICS_IL-8 release',
#  'ELISA_CXCL10/IP-10 release',
#  'multimer/tetramer_qualitative binding',
#  'beads,tetramer-sort_nan',
#  'cytometric bead array_TNFa release',
#  'cytometric bead array_IL-6 release',
#  'RNA/DNA detection_CCL5/RANTES release',
#  'peptide-restimulation,tetramer-sort_nan',
#  'cytometric bead array_IL-22 release',
#  'cytometric bead array_IL-5 release',
#  'tetramer-sort,antigen-loaded-targed_nan',
#  'cultured-T-cells,antigen-expressing-targets_nan',
#  'ICS_IL-22 release',
#  'bioassay_IL-4 release',
#  'ELISA_CCL3/MIP-1a release',
#  'antigen-loaded-targets, pentamer-sort_nan',
#  '3H-thymidine_proliferation',
# ...

# %%
['27252176_CAYSGGGADGLTF_2_Clear', '27252176_CQAGDTEAFF_Clear', '27252176_CAYSGGGADGLTF_1_Clear', '27252176_CATSGTYKYIF_Clear', '27252176_CALSGHDKVIF_Clear', '27252176_CAYTEDKIIF_Clear', '27252176_CASSMGGEQYF_Clear', '27252176_CASDSNTEAFF_Clear', '27252176_CASSLGEKLFF_Clear', '27252176_CASSRSLNVNSNQPQHF_Clear', '27252176_CASSQVRLNTEAFF_Clear', '27252176_CASSDDRGPYEQYF_Clear', '27252176_CASSMGGNPEQYF_Clear', '27252176_CAVFMDSNYQLIW_Clear', '27252176_CILDDNNDMRF_Clear', '27252176_CATSIDRGREKLFF_Clear', '27252176_CATSSGDLSSGANVLTF_Clear', '27252176_CALSEPYSGAGSYQLTF_Clear', '27252176_CASSVEGIDEKLFF_Clear', '27252176_CALLSSNTGKLIF_Clear', '27252176_CAHDTGNQFYF_Clear', '27252176_CASSEGDTEAFF_Clear